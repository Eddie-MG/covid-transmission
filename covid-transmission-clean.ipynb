# %%
from simulate import Simulate

# %%
sim = Simulate(1000000)

# %%
sim.run_simulation(20)
# Out:
# Creating dwellings and populating them
# Houses populated
# Total Population Size: 2497942 Total Outer Networks: 118
# Running simulation!!
#
# Day 0
# Person 88634 was infected first
#
# Day 1
# ----------Virus Report----------
#
# Today's new cases: 1
# Total Infected: 1
# Asymptomatic Cases: 0
# Symptomatic Cases: 1
# Total Recoveries: 0
# Total Deaths: 0
# Stay Home, Save Lives
#
# Day 2
# ----------Virus Report----------
#
# Today's new cases: 2
# Total Infected: 3
# Asymptomatic Cases: 1
# Symptomatic Cases: 2
# Total Recoveries: 0
# Total Deaths: 0
# Stay Home, Save Lives
#
# Day 3
# ----------Virus Report----------
#
# Today's new cases: 3
# Total Infected: 5
# Asymptomatic Cases: 2
# Symptomatic Cases: 3
# Total Recoveries: 0
# Total Deaths: 0
# Stay Home, Save Lives
#
# Day 4
# ----------Virus Report----------
#
# Today's new cases: 9
# Total Infected: 11
# Asymptomatic Cases: 5
# Symptomatic Cases: 6
# Total Recoveries: 0
# Total Deaths: 0
# Stay Home, Save Lives
#
# ...
